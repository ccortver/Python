# %% [markdown]
# # PRACTICA 2
#
# ### ¡Con todo lo aprendido con Python, vamos a resolver unos ejercicios de Bioinformática!
#
# #### 1.- Concatena las cadenas ATGCC y TCCG

# %%
cadena1 = "ATGCC"
cadena2 = "TCCG"

# %%
print(cadena1 + cadena2)
# Out:
# ATGCCTCCG

# %% [markdown]
# #### 2.- ¿Cuál es la longitud de ATGCGAGT?

# %%
dna="ATGCGAGT"

# %%
len (dna)
# Out:
# 8

# %% [markdown]
# #### 3.- Con la cadena mgXDyTw, ponla en mayúsculas, luego en minúsculas. Extrae su longitud y divide la cadena por la letra "g"

# %%
cadena ="mgXDyTw"

# %%
cadena_upper = cadena.upper()
print (cadena_upper)

cadena_lower = cadena.lower()
print (cadena_lower)

len(cadena)

cadena_divididaG = cadena.split("g")
print(cadena_divididaG)
# Out:
# MGXDYTW
# mgxdytw
# ['m', 'XDyTw']

# %% [markdown]
# #### 4.- Con la secuencia de aminoácidos vlspadktnv, reemplaza la valina con la tirosina. Pista: usa replace()

# %%
aa = "vlspadktnv"

# %%
aa_tirosina = aa.replace("v", "y")
print(aa_tirosina)
# Out:
# ylspadktny

# %% [markdown]
# #### 5.- Cuenta las valinas de la secuencia original anterior.

# %%
aa_valinas = aa.count("v")
print(aa_valinas)
# Out:
# 2

# %% [markdown]
# #### 6.- Con el diccionario siguiente imprime el valor de BisI y saca el valor de EcoRI con pop(). ¿Qué pasa con el diccionario?

# %%
enzR = {
    'EcoRI':r'GAATTC',
    'AvaII':r'GG(A|T)CC',
    'BisI':r'GC[ATGC]GC'
}

# %%
print(enzR['BisI'])
valor_pop = enzR.pop('EcoRI')
print("Valor con pop():", valor_pop)
print("Diccionario al usar pop():", enzR)
# Out:
# GC[ATGC]GC
# Valor con pop(): GAATTC
# Diccionario al usar pop(): {'AvaII': 'GG(A|T)CC', 'BisI': 'GC[ATGC]GC'}

# %% [markdown]
# Se elimina EcoRI del diccionario

# %% [markdown]
# #### 7.- Con la secuencia y la lista siguiente, escribe un algoritmo que cuente el número de veces que aparece un elemento de la lista en la secuencia. Pista: hacer un diccionario para almacenar los resultados puede ser buena idea

# %%
dna = "AATGATGAACGAC" 
dinucleotides = ['AA','AT','AG','AC', 
                 'TA','TT','TG','TC', 
                 'GA','GT','GG','GC', 
                 'CA','CT','CG','CT']

# %%
diccionario = {}
for x in dinucleotides:
    diccionario[x] = dna.count(x)

print(diccionario)
# Out:
# {'AA': 2, 'AT': 2, 'AG': 0, 'AC': 2, 'TA': 0, 'TT': 0, 'TG': 2, 'TC': 0, 'GA': 3, 'GT': 0, 'GG': 0, 'GC': 0, 'CA': 0, 'CT': 0, 'CG': 1}

# %% [markdown]
# ##### ¿Cuántos counts tiene TC?

# %%
print(dna.count("TC"))
# Out:
# 0

# %% [markdown]
# ##### ¿Puedes imprimir los dinuleótidos que tengan counts igual a 2?

# %%
for x, c in diccionario.items():
    if c == 2:
        print(x)
# Out:
# AA
# AT
# AC
# TG
